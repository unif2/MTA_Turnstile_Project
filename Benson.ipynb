# %%
import csv
import requests
import datetime
from collections import defaultdict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import calendar
import seaborn as sns
% matplotlib inline

#!curl -O http://web.mta.info/developers/data/nyct/turnstile/turnstile_160528.txt

# %%
mta_raw = defaultdict(list)
mta_dt = defaultdict(list)
mta_cum_entries = defaultdict(list)
mta_cum_exits = defaultdict(list)
mta_entries = defaultdict(list)
mta_exits = defaultdict(list)
mta_combined = defaultdict(list)
mta_master = defaultdict(list)
mta_traffic = defaultdict(list)

with open('Mar_Apr_May.txt') as f:
    reader = csv.reader(f)
    next(reader, None)
    for row in reader:
        key = tuple(row[:5])
        raw = row[6:]
        dt = datetime.datetime.strptime(row[6] + " " + row[7], '%m/%d/%Y %H:%M:%S')    
        cum_entries = row[9]
        cum_exits = row[10]
        mta_raw[key].append(raw)
        mta_dt[key].append(dt)
        mta_cum_entries[key].append(cum_entries)
        mta_cum_exits[key].append(cum_exits)

for k, v in mta_cum_entries.items():
    for x in range(len(v)-1):
        mta_entries[k].append(int(v[x+1])-int(v[x]))
        
for k, v in mta_cum_exits.items():
    for x in range(len(v)-1):
        mta_exits[k].append(int(v[x+1])-int(v[x]))

# %%
for k, v in mta_entries.items():
    for x in range(len(v)):
        if 0<= v[x] + mta_exits[k][x] <= 10000:
            mta_traffic[k].append(v[x] + mta_exits[k][x])
    
for k, v in mta_dt.items():
    pairs = zip(v, v, v, v, mta_traffic[k])
    mta_combined[k].append(pairs)

# %%
for k, v in mta_combined.items():
    l = ()
    for x in range(len(v[0])):
        month = datetime.date(1900, (datetime.datetime.date(v[0][x][0]).month), 1).strftime('%m')
        day = datetime.datetime.date(v[0][x][1])
        wday = datetime.datetime.isoweekday(v[0][x][2])
        interval = datetime.datetime.time(v[0][x][3])
        count = v[0][x][4]
        l = (month, day, wday, interval, count)
        mta_master[k].append(l)

# %%
mylist = []
for k,v in mta_master.items():
    for x in v:
        mylist.append([k[0],k[1],k[2],k[3],k[4],x[0],x[1],x[2],x[3],x[4]])

# %%
mylist[0]
# Out:
# ['R238A',
#  'R046',
#  '02-03-02',
#  'GRD CNTRL-42 ST',
#  '4567S',
#  '02',
#  datetime.date(2016, 2, 27),
#  6,
#  datetime.time(3, 0),
#  0]

# %%
df = pd.DataFrame(mylist, columns = ('C/A','Unit','SCP','Station','LineName','Month','Day','Weekday','Interval','Traffic'))

# %%
def calc_timeblock (t):  
   r =  int ( round ((t.minute + (t.hour*60.0)) / 240.0) % 6 )
   return r

# %%
df.head()
# Out:
#      C/A  Unit       SCP          Station LineName Month         Day  Weekday  \
# 0  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 1  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 2  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 3  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 4  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
#
#    Interval  Traffic
# 0  03:00:00        0
# 1  07:00:00        0
# 2  11:00:00        0
# 3  15:00:00        0
# 4  19:00:00        0

# %%
bin_4 = df["Interval"].apply(calc_timeblock)
df['TimeBlock'] = bin_4

# %%
df.head()
# Out:
#      C/A  Unit       SCP          Station LineName Month         Day  Weekday  \
# 0  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 1  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 2  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 3  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
# 4  R238A  R046  02-03-02  GRD CNTRL-42 ST    4567S    02  2016-02-27        6
#
#    Interval  Traffic  TimeBlock
# 0  03:00:00        0          1
# 1  07:00:00        0          2
# 2  11:00:00        0          3
# 3  15:00:00        0          4
# 4  19:00:00        0          5

# %%
pd.pivot_table(df, index = ['Station','LineName','Month','Weekday','TimeBlock'], values = ['Traffic'], aggfunc=np.sum)
# Out:
#                                             Traffic
# Station   LineName Month Weekday TimeBlock
# 1 AV      L        02    1       0             1614
#                                  1             1778
#                                  2            12125
#                                  3             6818
#                                  4            12148
#                                  5             7630
#                          6       0             6076
#                                  1             3018
#                                  2             5366
#                                  3             7886
#                                  4            10333
#                                  5            10430
#                          7       0             1743
#                                  1             1096
#                                  2             2973
#                                  3             7083
#                                  4             8168
#                                  5             5415
#                    03    1       0             3897
#                                  1            15336
#                                  2            43877
#                                  3            32022
#                                  4            48055
#                                  5            25805
#                          2       0             6439
#                                  1            18972
#                                  2            56629
#                                  3            38274
#                                  4            62192
#                                  5            37056
# ...                                             ...
# ZEREGA AV 6        05    5       5             1460
#                          6       0              353
#                                  1              878
#                                  2             1005
#                                  3             1191
#                                  4             1005
#                                  5              646
#                          7       0              207
#                                  1              527
#                                  2              939
#                                  3              956
#                                  4              903
#                                  5              970
#                    06    3       0              133
#                                  1             1651
#                                  2              890
#                                  3             1164
#                                  4             1242
#                                  5              397
#                          4       0              152
#                                  1             1685
#                                  2              789
#                                  3             1165
#                                  4             1193
#                                  5              369
#                          5       0              139
#                                  1             1592
#                                  2              777
#                                  3             1156
#                                  4             1115
#
# [75885 rows x 1 columns]

# %%
pt_total = pd.pivot_table(df, index = ['Station', 'LineName'], values = ['Traffic'], aggfunc=np.sum)
pt_total.sort_values(by=('Traffic'), ascending=False, inplace=True)
pt_total[0:25]
# Out:
#                               Traffic
# Station         LineName
# GRD CNTRL-42 ST 4567S        23629415
# 34 ST-HERALD SQ BDFMNQR      19570907
# TIMES SQ-42 ST  1237ACENQRS  13726452
# 34 ST-PENN STA  ACE          13199855
# 14 ST-UNION SQ  LNQR456      11906776
# 42 ST-PORT AUTH ACENQRS1237  11695782
# 86 ST           456          10535447
# 47-50 STS ROCK  BDFM          9804156
# FLUSHING-MAIN   7             9530830
# 59 ST COLUMBUS  ABCD1         8951253
# 59 ST           456NQR        8154578
# 34 ST-PENN STA  123ACE        7976603
# JKSN HT-ROOSVLT EFMR7         7924519
# W 4 ST-WASH SQ  ABCDEFM       7728210
# FULTON ST       2345ACJZ      7207444
# CANAL ST        JNQRZ6        6973915
# 96 ST           123           6911511
# LEXINGTON AV/53 EM6           6859914
# 42 ST-BRYANT PK BDFM7         6638486
# 72 ST           123           6603813
# JAMAICA CENTER  EJZ           6161561
# 34 ST-PENN STA  123           5888845
# 77 ST           6             5768769
# 14 ST-UNION SQ  456LNQR       5763688
# JAY ST-METROTEC ACF           5376123

# %%
pt_month = pd.pivot_table(df, index = ['Station', 'LineName'], columns = ['Month'], values = ['Traffic'], aggfunc=np.sum, margins=True, fill_value=0)
pt_month.sort_values(by=('Traffic', 'All'), ascending=False, inplace=True)
pt_month[0:10]
# Out:
#                                 Traffic                            \
# Month                                02           03           04
# Station         LineName
# All                          20580766.0  284530273.0  268613631.0
# GRD CNTRL-42 ST 4567S          482166.0    7778408.0    7218010.0
# 34 ST-HERALD SQ BDFMNQR        447556.0    6348606.0    5959748.0
# TIMES SQ-42 ST  1237ACENQRS    328408.0    4470365.0    4170163.0
# 34 ST-PENN STA  ACE            277181.0    4283178.0    4052036.0
# 14 ST-UNION SQ  LNQR456        289924.0    3820211.0    3665233.0
# 42 ST-PORT AUTH ACENQRS1237    275091.0    3784774.0    3568634.0
# 86 ST           456            253800.0    3310316.0    3241365.0
# 47-50 STS ROCK  BDFM           195927.0    3190185.0    2977066.0
# FLUSHING-MAIN   7              242378.0    3004676.0    2909176.0
#
#
# Month                                 05          06          All
# Station         LineName
# All                          276133541.0  30757618.0  880615829.0
# GRD CNTRL-42 ST 4567S          7267677.0    883154.0   23629415.0
# 34 ST-HERALD SQ BDFMNQR        6130288.0    684709.0   19570907.0
# TIMES SQ-42 ST  1237ACENQRS    4296716.0    460800.0   13726452.0
# 34 ST-PENN STA  ACE            4114915.0    472545.0   13199855.0
# 14 ST-UNION SQ  LNQR456        3725386.0    406022.0   11906776.0
# 42 ST-PORT AUTH ACENQRS1237    3676473.0    390810.0   11695782.0
# 86 ST           456            3361223.0    368743.0   10535447.0
# 47-50 STS ROCK  BDFM           3070661.0    370317.0    9804156.0
# FLUSHING-MAIN   7              3055128.0    319472.0    9530830.0

# %%
pt_weekday = pd.pivot_table(df, index = ['Station', 'LineName'], columns = ['Weekday'], values = ['Traffic'], aggfunc=np.sum, margins=True, fill_value=0)
pt_weekday.sort_values(by=('Traffic', 'All'), ascending=False, inplace=True)
pt_weekday[0:10]
# Out:
#                                  Traffic                            \
# Weekday                                1            2            3
# Station         LineName
# All                          136774414.0  147755486.0  150304941.0
# GRD CNTRL-42 ST 4567S          3921619.0    4302755.0    4294903.0
# 34 ST-HERALD SQ BDFMNQR        3001074.0    3246832.0    3332899.0
# TIMES SQ-42 ST  1237ACENQRS    1945806.0    2162051.0    2260905.0
# 34 ST-PENN STA  ACE            2099276.0    2235281.0    2259063.0
# 14 ST-UNION SQ  LNQR456        1741765.0    1898180.0    1982555.0
# 42 ST-PORT AUTH ACENQRS1237    1780669.0    1868411.0    1904289.0
# 86 ST           456            1587773.0    1735299.0    1744574.0
# 47-50 STS ROCK  BDFM           1625232.0    1795608.0    1826474.0
# FLUSHING-MAIN   7              1475821.0    1548116.0    1570550.0
#
#                                                                                \
# Weekday                                4            5           6           7
# Station         LineName
# All                          150220025.0  143518975.0  85616406.0  66425582.0
# GRD CNTRL-42 ST 4567S          4324688.0    3982170.0   1598164.0   1205116.0
# 34 ST-HERALD SQ BDFMNQR        3334583.0    3301184.0   1919011.0   1435324.0
# TIMES SQ-42 ST  1237ACENQRS    2262558.0    2223453.0   1618147.0   1253532.0
# 34 ST-PENN STA  ACE            2283937.0    2230854.0   1155312.0    936132.0
# 14 ST-UNION SQ  LNQR456        1961627.0    1940730.0   1378089.0   1003830.0
# 42 ST-PORT AUTH ACENQRS1237    1914953.0    1935667.0   1271497.0   1020296.0
# 86 ST           456            1746150.0    1724260.0   1137711.0    859680.0
# 47-50 STS ROCK  BDFM           1826573.0    1719155.0    572419.0    438695.0
# FLUSHING-MAIN   7              1552470.0    1515897.0   1048533.0    819443.0
#
#
# Weekday                              All
# Station         LineName
# All                          880615829.0
# GRD CNTRL-42 ST 4567S         23629415.0
# 34 ST-HERALD SQ BDFMNQR       19570907.0
# TIMES SQ-42 ST  1237ACENQRS   13726452.0
# 34 ST-PENN STA  ACE           13199855.0
# 14 ST-UNION SQ  LNQR456       11906776.0
# 42 ST-PORT AUTH ACENQRS1237   11695782.0
# 86 ST           456           10535447.0
# 47-50 STS ROCK  BDFM           9804156.0
# FLUSHING-MAIN   7              9530830.0

# %%
pt_day = pd.pivot_table(df, index = ['Station', 'LineName'], columns = ['Day'], values = ['Traffic'], aggfunc=np.sum, margins=True, fill_value=0)
pt_day.sort_values(by=('Traffic', 'All'), ascending=False, inplace=True)
pt_day_10 = pt_day[0:11]
pt_day_rm_row = pt_day_10['Traffic'].iloc[1:]
pt_day_final = pt_day_rm_row.T.iloc[:-1]

# %%
#pt_day_final.plot(kind='box', figsize=[16,8])
pt_day_final
# Out:
# Station    GRD CNTRL-42 ST 34 ST-HERALD SQ TIMES SQ-42 ST 34 ST-PENN STA  \
# LineName             4567S         BDFMNQR    1237ACENQRS            ACE
# Day
# 2016-02-27        109601.0        133807.0       112235.0        69963.0
# 2016-02-28         80914.0         97620.0        83260.0        53555.0
# 2016-02-29        291651.0        216129.0       132913.0       153663.0
# 2016-03-01        302402.0        225397.0       145663.0       161067.0
# 2016-03-02        307509.0        225835.0       152391.0       156098.0
# 2016-03-03        315047.0        232763.0       152307.0       163401.0
# 2016-03-04        301375.0        234262.0       155637.0       162245.0
# 2016-03-05        114266.0        141708.0       114639.0        74145.0
# 2016-03-06         81957.0        101128.0        84705.0        56768.0
# 2016-03-07        295137.0        221275.0       146461.0       153467.0
# 2016-03-08        305007.0        230197.0       155982.0       161188.0
# 2016-03-09        304625.0        232978.0       163613.0       159251.0
# 2016-03-10        309923.0        230293.0       163535.0       162141.0
# 2016-03-11        300806.0        241097.0       167507.0       164161.0
# 2016-03-12        120568.0        143040.0       123619.0        73891.0
# 2016-03-13         83728.0        100192.0        84828.0        52405.0
# 2016-03-14        311166.0        215963.0       140516.0       155476.0
# 2016-03-15        305788.0        230758.0       156674.0       159815.0
# 2016-03-16        311362.0        235474.0       163344.0       161423.0
# 2016-03-17        324306.0        240596.0       166354.0       165009.0
# 2016-03-18        300973.0        240497.0       166744.0       164405.0
# 2016-03-19        110546.0        135108.0       119800.0        84418.0
# 2016-03-20         82120.0        105064.0        95578.0        69814.0
# 2016-03-21        298506.0        227085.0       145723.0       157859.0
# 2016-03-22        306065.0        238752.0       156310.0       158829.0
# 2016-03-23        308144.0        246775.0       165194.0       161355.0
# 2016-03-24        313266.0        249571.0       169215.0       167890.0
# 2016-03-25        233166.0        226859.0       159454.0       145227.0
# 2016-03-26        118784.0        141921.0       129196.0        94367.0
# 2016-03-27         91426.0         95537.0        97586.0        82499.0
# ...                    ...             ...            ...            ...
# 2016-05-05        310930.0        239968.0       162369.0       164824.0
# 2016-05-06        303310.0        242780.0       161632.0       165525.0
# 2016-05-07        117882.0        142471.0       113545.0        83528.0
# 2016-05-08         90113.0         99785.0        87807.0        66777.0
# 2016-05-09        287445.0        222119.0       145228.0       154921.0
# 2016-05-10        302801.0        230067.0       154890.0       157597.0
# 2016-05-11        302841.0        235110.0       161436.0       157098.0
# 2016-05-12        310274.0        236195.0       161536.0       162051.0
# 2016-05-13        275781.0        238841.0       159582.0       162164.0
# 2016-05-14        115751.0        148746.0       113550.0        75360.0
# 2016-05-15         96353.0        117598.0        91216.0        65421.0
# 2016-05-16        296894.0        232177.0       149063.0       159871.0
# 2016-05-17        323067.0        240171.0       163823.0       162548.0
# 2016-05-18        289588.0        250217.0       168248.0       167899.0
# 2016-05-19        296372.0        243913.0       167230.0       165190.0
# 2016-05-20        286886.0        248192.0       167859.0       162316.0
# 2016-05-21        119435.0        136907.0       113092.0        85742.0
# 2016-05-22         89409.0        101708.0        89457.0        67404.0
# 2016-05-23        292500.0        227704.0       147984.0       156076.0
# 2016-05-24        314248.0        237599.0       153390.0       162196.0
# 2016-05-25        303094.0        246294.0       162923.0       164737.0
# 2016-05-26        303163.0        241161.0       161572.0       163896.0
# 2016-05-27        259694.0        235565.0       153080.0       154133.0
# 2016-05-28        106260.0        120614.0       114334.0        81956.0
# 2016-05-29         95344.0        102802.0       100377.0        71230.0
# 2016-05-30         89001.0        104459.0        79571.0        71467.0
# 2016-05-31        291406.0        224991.0       150367.0       156422.0
# 2016-06-01        306423.0        239852.0       163042.0       162879.0
# 2016-06-02        308322.0        238132.0       164535.0       163859.0
# 2016-06-03        268409.0        206725.0       133223.0       145807.0
#
# Station    14 ST-UNION SQ 42 ST-PORT AUTH     86 ST 47-50 STS ROCK  \
# LineName          LNQR456     ACENQRS1237       456           BDFM
# Day
# 2016-02-27        93314.0         80821.0   79259.0        45183.0
# 2016-02-28        70951.0         65833.0   58707.0        31336.0
# 2016-02-29       125659.0        128437.0  115834.0       119408.0
# 2016-03-01       132305.0        130052.0  121342.0       123787.0
# 2016-03-02       133896.0        136288.0  119876.0       128229.0
# 2016-03-03       134656.0        138756.0  120375.0       128539.0
# 2016-03-04       133364.0        139627.0  123024.0       126168.0
# 2016-03-05        94522.0         84981.0   80706.0        44926.0
# 2016-03-06        71329.0         65891.0   58636.0        31956.0
# 2016-03-07       131557.0        129481.0  117832.0       121227.0
# 2016-03-08       138727.0        127670.0  122743.0       120705.0
# 2016-03-09       144078.0        134441.0  123710.0       121476.0
# 2016-03-10       140457.0        135536.0  121872.0       121122.0
# 2016-03-11       144845.0        141291.0  125599.0       122870.0
# 2016-03-12        99210.0         86099.0   80126.0        43891.0
# 2016-03-13        70712.0         65226.0   57307.0        30934.0
# 2016-03-14       122903.0        137205.0  119428.0       123154.0
# 2016-03-15       140234.0        136355.0  125549.0       123093.0
# 2016-03-16       141916.0        136266.0  124953.0       125448.0
# 2016-03-17       140844.0        139603.0  129454.0       132602.0
# 2016-03-18       144957.0        148099.0  126240.0       123581.0
# 2016-03-19       120138.0         90635.0   79586.0        37203.0
# 2016-03-20        83321.0         74253.0   60530.0        29958.0
# 2016-03-21       127119.0        133635.0  115314.0       125002.0
# 2016-03-22       133506.0        134432.0  119011.0       129796.0
# 2016-03-23       138730.0        135001.0  118706.0       130129.0
# 2016-03-24       139045.0        142214.0  119982.0       129604.0
# 2016-03-25       130680.0        129690.0  107466.0       103323.0
# 2016-03-26        90858.0        101055.0   72662.0        47870.0
# 2016-03-27        57350.0         82116.0   51088.0        42518.0
# ...                   ...             ...       ...            ...
# 2016-05-05       144219.0        138340.0  125368.0       134153.0
# 2016-05-06       138798.0        143540.0  131799.0       130291.0
# 2016-05-07        98143.0         93208.0  105537.0        39246.0
# 2016-05-08        68291.0         74263.0   79845.0        29510.0
# 2016-05-09       133229.0        130287.0  116313.0       123352.0
# 2016-05-10       139684.0        132380.0  123852.0       129563.0
# 2016-05-11       145453.0        134170.0  126737.0       131007.0
# 2016-05-12       147229.0        134565.0  127422.0       131050.0
# 2016-05-13       140758.0        142452.0  129694.0       129981.0
# 2016-05-14       112836.0         88703.0   80106.0        48071.0
# 2016-05-15        78811.0         74731.0   63676.0        38655.0
# 2016-05-16       137282.0        131148.0  120851.0       127257.0
# 2016-05-17       140603.0        136661.0  128324.0       136097.0
# 2016-05-18       145767.0        139917.0  130925.0       139812.0
# 2016-05-19       143448.0        141186.0  129478.0       140270.0
# 2016-05-20       145576.0        140651.0  131059.0       133512.0
# 2016-05-21        98515.0         93931.0   84040.0        42651.0
# 2016-05-22        81528.0         75270.0   64112.0        31341.0
# 2016-05-23       130628.0        130389.0  122085.0       124738.0
# 2016-05-24       134108.0        137625.0  127660.0       132640.0
# 2016-05-25       144651.0        137466.0  128245.0       132517.0
# 2016-05-26       138138.0        136519.0  127763.0       130859.0
# 2016-05-27       133804.0        133543.0  118433.0       113868.0
# 2016-05-28        81943.0         97328.0   67887.0        32231.0
# 2016-05-29        62981.0         82425.0   57784.0        27532.0
# 2016-05-30        60251.0         75384.0   57487.0        25925.0
# 2016-05-31       130156.0        130349.0  121016.0       120152.0
# 2016-06-01       141853.0        134725.0  127749.0       128118.0
# 2016-06-02       139672.0        135796.0  127502.0       129162.0
# 2016-06-03       124497.0        120289.0  113492.0       113037.0
#
# Station    FLUSHING-MAIN 59 ST COLUMBUS
# LineName               7          ABCD1
# Day
# 2016-02-27       75387.0        57476.0
# 2016-02-28       57801.0        47268.0
# 2016-02-29      109190.0        99466.0
# 2016-03-01      110836.0       104882.0
# 2016-03-02      109556.0       105278.0
# 2016-03-03      109053.0       106960.0
# 2016-03-04      110648.0        95362.0
# 2016-03-05       69349.0        58951.0
# 2016-03-06       58583.0        46184.0
# 2016-03-07      108836.0       103949.0
# 2016-03-08      110057.0       107328.0
# 2016-03-09      110216.0       111767.0
# 2016-03-10      109730.0       110026.0
# 2016-03-11      107918.0        99371.0
# 2016-03-12       74613.0        65791.0
# 2016-03-13       51986.0        45735.0
# 2016-03-14      103267.0        99121.0
# 2016-03-15      109535.0       105900.0
# 2016-03-16      109945.0       110188.0
# 2016-03-17      109945.0       108494.0
# 2016-03-18      109421.0        98299.0
# 2016-03-19       71466.0        61395.0
# 2016-03-20       52465.0        48488.0
# 2016-03-21      105500.0        98232.0
# 2016-03-22      108774.0       103114.0
# 2016-03-23      109214.0        99726.0
# 2016-03-24      110107.0       104233.0
# 2016-03-25       95301.0        82508.0
# 2016-03-26       74071.0        63694.0
# 2016-03-27       56629.0        48437.0
# ...                  ...            ...
# 2016-05-05      111662.0       117142.0
# 2016-05-06      107710.0       102876.0
# 2016-05-07       75858.0        69745.0
# 2016-05-08       59169.0        56798.0
# 2016-05-09      111347.0       112162.0
# 2016-05-10      113882.0       114515.0
# 2016-05-11      114699.0       117289.0
# 2016-05-12      112969.0       119917.0
# 2016-05-13      113025.0       103887.0
# 2016-05-14       83985.0        75093.0
# 2016-05-15       64585.0        59679.0
# 2016-05-16      111872.0       110789.0
# 2016-05-17      115223.0       115133.0
# 2016-05-18      116859.0       119091.0
# 2016-05-19      114270.0       113762.0
# 2016-05-20      115128.0       109446.0
# 2016-05-21       77452.0        68529.0
# 2016-05-22       65155.0        57003.0
# 2016-05-23      113189.0       107819.0
# 2016-05-24      111408.0       109374.0
# 2016-05-25      115783.0       115948.0
# 2016-05-26      114262.0       112335.0
# 2016-05-27      114058.0        95839.0
# 2016-05-28       76766.0        61517.0
# 2016-05-29       64295.0        55014.0
# 2016-05-30       63868.0        45918.0
# 2016-05-31      112206.0       100253.0
# 2016-06-01      113108.0       103218.0
# 2016-06-02      112950.0       107665.0
# 2016-06-03       93414.0        85572.0
#
# [98 rows x 10 columns]

# %%
sns.set(style="ticks")
sns.set_style("whitegrid")

# Load the example tips dataset
#tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and sex
labels = ['GRD CTR-42ST', '34 ST-HERALD SQ', 'TIME SQ-42ST', '34ST-PENN ST', '14ST-UNION SQ', '42ST-PORT AUTH', '86ST', '47-50ST ROCK', 'FLUSH-MAIN', '59ST COLUM']
bp = sns.boxplot(data=pt_day_final, palette="PRGn")
sns.despine(offset=20, trim=True)
bp.set_xticklabels(labels, rotation=45)
bp.set(xlabel='Station', ylabel='Daily Traffic')
# Out:
# [<matplotlib.text.Text at 0x1b541df10>, <matplotlib.text.Text at 0x1b5189a90>]

# %%
pt_tb = pd.pivot_table(df, index = ['Station','LineName'], columns = ['TimeBlock'], values = ['Traffic'], aggfunc=np.sum, margins=True, fill_value=0)
pt_tb.sort_values(by=('Traffic', 'All'), ascending=False, inplace=True)
pt_tb_10 = pt_tb[0:10]
pt_tb_10
pt_tb_rm_row = pt_tb_10['Traffic'].iloc[1:]
pt_tb_final = pt_tb_rm_row.T.iloc[:-1]

# %%
#pt_interval_final[(pt_interval_final.T != 0).any()].T
#pt_tb_final.T
labels = ['10pm-2am', '2am-6am', '6am-10am', '10am-2pm', '2pm-6pm', '6pm-10pm']
hm = sns.heatmap(pt_tb_final.T, cmap='Blues')
hm.set_xticklabels(labels, rotation=45)
# Out:
# [<matplotlib.text.Text at 0x1b66d23d0>,
#  <matplotlib.text.Text at 0x1b66dc110>,
#  <matplotlib.text.Text at 0x1b6556f90>,
#  <matplotlib.text.Text at 0x1b655e4d0>,
#  <matplotlib.text.Text at 0x1b655eb90>,
#  <matplotlib.text.Text at 0x1b65682d0>]

# %%
#pt_tb_final.T.plot()
